# %%
# %matplotlib inline
from IPython.display import Latex, display
import numpy as np
from numpy import genfromtxt
import scipy as sp
import matplotlib.pylab as plt
from matplotlib.ticker import (MultipleLocator, AutoMinorLocator)
from IPython.display import Markdown
import seaborn as sns
from scipy.interpolate import interp1d
import datetime
from astropy.time import Time
from datetime import timedelta
import pandas as pd

plt.style.use('default')
params = {'legend.fontsize': '20',
          'figure.figsize': (18, 10),
         'axes.labelsize': '18',
         'axes.titlesize':'25',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large',
         'xtick.minor.visible' : True,
         'ytick.minor.visible' : True,
         'axes.grid' : True,
         'grid.linewidth' : '0.5',
         'grid.linestyle' : '-',
         'text.usetex': False,
         'svg.fonttype': 'none'}
plt.rcParams.update(params)

# %% [markdown]
# # 1) Analyse AX Vel

# %%
#quelques données 
P = 2.592891 #period AX Vel [day]
Mid = 2443878.253 #epoch [HJD]

a = 8.1 # HD 68395 mag V
b = 8.25 # HD 68515 mag V
c = 8.56 # HD 68630 mag V
d = 8.59 # HD 68477 mag V

def f_phase(date):
    return np.mod((date-Mid)/P,1)

def f_mag(target,comparison,comparison_mag):
    return -2.5*(np.log10(target/comparison))+comparison_mag

#Ouverture des datas
data_brut = pd.read_csv('data_brut.txt',sep="\t",index_col=False)
air_mass = pd.read_csv('air_mass.txt',index_col=False)

#calcul mag
results = pd.DataFrame({'phase': f_phase(data_brut['date [HJD]']),
                           'AX Vel from a': f_mag(data_brut['AX Vel [ADU]'],data_brut['HD 68395 [ADU]'],a),
                           'AX Vel from b': f_mag(data_brut['AX Vel [ADU]'],data_brut['HD 68515 [ADU]'],b),
                           'AX Vel from c': f_mag(data_brut['AX Vel [ADU]'],data_brut['HD 68630 [ADU]'],c),
                           'AX Vel from d': f_mag(data_brut['AX Vel [ADU]'],data_brut['HD 68477 [ADU]'],d),
                           'HD 68395 from b': f_mag(data_brut['HD 68395 [ADU]'],data_brut['HD 68515 [ADU]'],b),
                           'HD 68395 from c': f_mag(data_brut['HD 68395 [ADU]'],data_brut['HD 68630 [ADU]'],c),
                           'HD 68395 from d': f_mag(data_brut['HD 68395 [ADU]'],data_brut['HD 68477 [ADU]'],d)})

#calcul mean et tout
n_obs = int((len(results['phase'])+1)/10)

date_mean = []
phase_mean = []
a_mean = []
b_mean = []
c_mean = []
d_mean = []
mag_mean = []
std = []

b_mean_check = []
c_mean_check = []
d_mean_check = []
mag_mean_check = []
std_check = []

mean_adu = []
std_adu = []

for i in range(n_obs):
    date_mean.append(data_brut['date [HJD]'][4+(i*10)])
    phase_mean.append(results['phase'][4+(i*10)])
    a_mean.append(np.mean(results['AX Vel from a'][0+(i*10):10+(i*10)]))
    b_mean.append(np.mean(results['AX Vel from b'][0+(i*10):10+(i*10)]))
    c_mean.append(np.mean(results['AX Vel from c'][0+(i*10):10+(i*10)]))
    d_mean.append(np.mean(results['AX Vel from d'][0+(i*10):10+(i*10)]))
    
    b_mean_check.append(np.mean(results['HD 68395 from b'][0+(i*10):10+(i*10)]))
    c_mean_check.append(np.mean(results['HD 68395 from c'][0+(i*10):10+(i*10)]))
    d_mean_check.append(np.mean(results['HD 68395 from d'][0+(i*10):10+(i*10)]))
    
    
    pre_out = [a_mean[i],b_mean[i],c_mean[i],d_mean[i]]
    mag_mean.append(np.mean(pre_out))
    std.append(np.std(pre_out))
    
    pre_out_check = [b_mean_check[i],c_mean_check[i],d_mean_check[i]]
    mag_mean_check.append(np.mean(pre_out_check))
    std_check.append(np.std(pre_out_check))
    
    mean_adu.append(np.mean(data_brut['AX Vel [ADU]'][0+(i*10):10+(i*10)]))
    std_adu.append(np.std(data_brut['AX Vel [ADU]'][0+(i*10):10+(i*10)]))
    
    
results_mean = pd.DataFrame({'date [HJD]' : date_mean,
                             'phase': phase_mean,
                             'mean AX Vel [mag]' : mag_mean,
                             'std AX Vel [mag]' : std,
                             'mean AX Vel [ADU]' : mean_adu,
                             'std AX Vel [ADU]' : std_adu,
                             'mean HD 68395 [mag]' : mag_mean_check,
                             'std HD 68395 [mag]' : std_check,
                             'air mass [x zénithale]': air_mass["air mass [x masse d'air zenithale]"]
                            })

# %%
results_mean
# Out:
#     date [HJD]     phase  mean AX Vel [mag]  std AX Vel [mag]  \
# 0  2459331.884  0.000247           8.273538          0.035194
# 1  2459350.992  0.369627           8.019474          0.507616
# 2  2459353.924  0.500411           8.013141          0.030464
# 3  2459354.901  0.877211           8.280928          0.028907
# 4  2459355.872  0.251696           8.319940          0.021303
# 5  2459356.867  0.635438           8.172680          0.026258
# 6  2459363.964  0.372537           8.195981          0.023999
# 7  2459365.922  0.127679           8.244653          0.027087
#
#    mean AX Vel [ADU]  std AX Vel [ADU]  mean HD 68395 [mag]  \
# 0           111824.3       1449.107798             8.098666
# 1             3427.6        219.875055             8.756213
# 2           136445.1       5342.816831             8.089311
# 3           105014.5       2156.016987             8.128118
# 4           105792.5       1096.247987             8.099130
# 5           121763.4       1962.997310             8.082167
# 6           104853.5       1077.009308             8.083715
# 7            82500.1       3538.127823             8.073431
#
#    std HD 68395 [mag]  air mass [x zénithale]
# 0            0.040633                  1.0813
# 1            0.485707                  1.9480
# 2            0.034768                  1.4130
# 3            0.030273                  1.3020
# 4            0.024595                  1.2040
# 5            0.028979                  1.1960
# 6            0.026489                  2.0770
# 7            0.028316                  1.6460

# %%
#Retrait observation 16 mai 

results_crop = results.drop(results.index[10:21])
results_mean_crop = results_mean.drop([1])

fig, ax = plt.subplots()

ax.plot(results_crop['phase'], results_crop['AX Vel from a'], lw=1, color='b', marker='X',linestyle = 'none', markersize=5, label=('Mesures de a'))
ax.plot(results_crop['phase'], results_crop['AX Vel from b'], lw=1, color='r', marker='o',linestyle = 'none', markersize=5, label=('Mesures de b'))
ax.plot(results_crop['phase'], results_crop['AX Vel from c'], lw=1, color='g', marker='v',linestyle = 'none', markersize=5, label=('Mesures de c'))
ax.plot(results_crop['phase'], results_crop['AX Vel from d'], lw=1, color='y', marker='s',linestyle = 'none', markersize=5, label=('Mesures de d'))
#ax.plot(results_mean_crop['phase'], results_mean_crop['mean AX Vel [mag]'], markersize=20, color='b', marker='o',linestyle = 'none', label=('Mesures moyennes'))
#ax.errorbar(results_mean_crop['phase'], results_mean_crop['mean AX Vel [mag]'], yerr=results_mean_crop['std AX Vel [mag]'], lw=3, markeredgewidth=3, markersize=10, capsize=8, color='k',   marker='s',linestyle = 'none', label=('Mesures moyennes'))

ax.invert_yaxis()




ax.set_title('Courbe de luminosité de AX Vel', pad=20)
ax.set_ylabel('Magnitude V [mag]')
ax.set_xlabel('Phase')
lgnd = ax.legend(loc='best', frameon=True, markerscale = 0.7)


lgnd.legendHandles[0]._legmarker.set_markersize(8)
lgnd.legendHandles[1]._legmarker.set_markersize(8)
lgnd.legendHandles[2]._legmarker.set_markersize(8)
lgnd.legendHandles[3]._legmarker.set_markersize(8)

plt.show()

# %%
#Retrait observation 16 mai 
results_mean_crop = results_mean.drop([1])
    
fig, ax = plt.subplots()


ax.errorbar(results_mean_crop['phase'], results_mean_crop['mean AX Vel [mag]'], yerr=results_mean_crop['std AX Vel [mag]'], lw=1, color='k',  capsize=4, marker='s',
            linestyle = 'none', label=('Mesures moyennes'))

ax.invert_yaxis()

ax.set_title('Courbe de luminosité de AX Vel', pad=20)
ax.set_ylabel('Magnitude V [mag]')
ax.set_xlabel('Phase')
ax.legend(loc='best', frameon=True)

plt.show()

# %%
fig3, ax3 = plt.subplots()

ax3.errorbar(results_mean["air mass [x zénithale]"], results_mean["mean AX Vel [ADU]"], yerr=results_mean["std AX Vel [ADU]"], lw=1, color='k',  capsize=3, marker='s',
            linestyle = 'none', label=('Mesures'))

ax3.set_title("Intensité moyenne de AX Vel par observation en fonction de la masse d'air", pad=20)
ax3.set_ylabel("Intensité moyenne de AX Vel [ADU]")
ax3.set_xlabel("Masse d'air [masse d'air zénitale]")
ax3.legend(loc='best', frameon=True)



ax3.annotate('Observation du 16 mai 2021\nprésence probable de nuages', xy = (1.937, 6000),  xycoords='data',
                xytext = (-300,70 ), textcoords = 'offset points',
                arrowprops = {'color': 'black', 'width': 1.5,
                              'headwidth': 8, 'alpha': 0.7},
                bbox=dict(boxstyle="round",pad=0.4, fc="none", ec="black"),
                fontsize=14)

plt.savefig('graphes/meanadu_airmass.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# # 2) Validation photométrie

# %%
t = Time([results_mean['date [HJD]']], format='jd', out_subfmt='date')
date2 = t.tt.datetime[0]

# %%
fig4, ax4 = plt.subplots()

ax4.errorbar(date2, results_mean['mean HD 68395 [mag]'], yerr=results_mean['std HD 68395 [mag]'], lw=1, color='k',  capsize=3, marker='s',linestyle = 'none', label=('Mesures'))

ax4.set_title('Calcul de la magnitude de HD 68395 sur base de la photométrie par observations', pad=20)
ax4.set_ylabel('Magnitude V [mag]')
ax4.set_xlabel("Date [UTC]")
ax4.legend(loc='best', frameon=True)
ax4.invert_yaxis()

ax4.axhline(y=8.1, color='g', linestyle='--')
ax4.text(0.1, 0.86,'Magnitude de référence pour HD 68395 (SIMBAD)',
                fontsize=14, color='green', transform=ax4.transAxes)

ax4.annotate('Observation non utilisable', xy = (date2[1]-timedelta(days=0, hours=5, minutes=0), 8.74),
                xycoords='data',
                xytext = (-300,70 ), textcoords = 'offset points',
                arrowprops = {'color': 'black', 'width': 1.5,
                              'headwidth': 8, 'alpha': 0.7},
                bbox=dict(boxstyle="round",pad=0.4, fc="none", ec="black"),
                fontsize=14)

plt.gcf().autofmt_xdate()
plt.savefig('graphes/HD_check.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# # 3) Comparaison avec les données de l'article de Susan L. Barrell

# %%
#Ouverture des datas de susan
data_susan = pd.read_csv('data_susan_barrell.txt',sep=",",index_col=False)

data_susan = (data_susan[data_susan['V [mag]'] < 8.6]) # valeur qui deconne en 8.8

date_susan = data_susan['HJD (-2443000)'] + 2443000
mag_susan = data_susan['V [mag]']

# %%
P_susan = 2.592891
mid_susan = 2443878.253 + 1/2*P_susan # Pourquoi le + 1/2 pour que ça fit ?
phase_susan = np.mod((date_susan-mid_susan)/P_susan,1)

# %%
#Retrait observation 16 mai 
results_mean_crop = results_mean.drop([1])

fig, ax = plt.subplots()

ax.plot(phase_susan, mag_susan, lw=1, color='k', marker='s', linestyle = 'none', label=('Mesures de Susan L. Barrell'))
ax.errorbar(results_mean_crop['phase'], results_mean_crop['mean AX Vel [mag]'], yerr=results_mean_crop['std AX Vel [mag]'], lw=1, color='r',  capsize=4, marker='s',
            linestyle = 'none', label=('Mesures moyennes'))
ax.invert_yaxis()


ax.set_title('Courbe de luminosité de AX Vel - comparaison avec les mesures de Susan L. Barrell', pad=20)
ax.set_ylabel('Magnitude V [mag]')
ax.set_xlabel('Phase')
ax.legend(loc='best', frameon=True)

plt.savefig('graphes/litterature_vs_nous.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# # 4) Estimation de la distance de AX Vel

# %%
p_gaia = 0.6799677466559306E-3 #arcsec
D_th = 1/p_gaia


a = -4.05
b = -2.43
P = 2.592891
m_V = np.mean(results_mean.drop([1])['mean AX Vel [mag]']) #sans l'observation raté du 16 mai
K = 6.403
A = 0

M = a + b*(np.log10(P) - 1)
D = 10**((m_V - M + 5 - A) / 5)
err = np.abs((1 - (D/D_th))*100)

print('D =',"{:.2f}".format(D),'[pc]')
print('D_GAIA =',"{:.2f}".format(D_th),'[pc]')
print('Erreur de',"{:.2f}".format(err),'%','par rapport à Gaia')
# Out:
# D = 1472.25 [pc]
# D_GAIA = 1470.66 [pc]
# Erreur de 0.11 % par rapport à Gaia

# %% [markdown]
# # 5) PSF saturé

# %%
#PSF AX Vel saturé
data_sature = pd.read_csv('obs_16_mai_sature.txt',sep=" ",index_col=False, na_values=['-9999'])
print(data_sature)
# Out:
#      radius     ADU
# 0         0  1000.0
# 1         1     NaN
# 2         2     NaN
# 3         3     NaN
# 4         4     NaN
# ..      ...     ...
# 110     110     0.0
# 111     111     0.0
# 112     112     0.0
# 113     113     0.0
# 114     114     0.0
#
# [115 rows x 2 columns]

# %%
#Encodage des datas, selectionner datas 1 to 70: 1= enlever le max 70= cropper les datas
radius = data_sature.iloc[1:70 , 0]
sat_adu = data_sature.iloc[1:70 , 1]

# %%
figsat, axsat = plt.subplots()

axsat.plot(radius, sat_adu, color='k', marker = 's', linestyle = "none", label = "Mesures du 23/04/2021")

axsat.set_title('Profil photométrique de AX Vel', pad=20)
axsat.set_xlabel('Rayon [pixel x10]')
axsat.set_ylabel("Intensité reçue [ADU]")
axsat.legend(loc='best', frameon=True)

plt.savefig('graphes/sature.pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# # 6) Etude reglages télescope

# %%
#images fournies pour HD5505 - T5
data_T5 = pd.read_csv('ADU_HD5505_T5.txt',sep=",",index_col=False)
print(data_T5)
# Out:
#     exposure [s]     ADU
# 0              2   25752
# 1              4   52215
# 2              8  104886
# 3             12  156629
# 4             16  208363
# 5             20  252273
# 6             25  304725
# 7             30  343192
# 8             35  385778
# 9             40  418215
# 10            50  489888
# 11            60  536291

# %%
#Encodage des datas séparation lineaire et quadratique
hd5505_t1 = data_T5.iloc[0:5 , 0]
hd5505_adu1 = data_T5.iloc[0:5 , 1]

hd5505_t2 = data_T5.iloc[5:12 , 0]
hd5505_adu2 = data_T5.iloc[5:12 , 1]

# %%
#fit linéaire
coef1 = np.polyfit(hd5505_t1, hd5505_adu1, 1)
print("fit linéaire : f(x) =",coef1[0],"x +",coef1[1])
#fit ^2
coef2 = np.polyfit(hd5505_t2, hd5505_adu2, 2)
print("fit quadratique : g(x) =",coef2[0],"x^2 +",coef2[1],"x +",coef2[2])

fit1 = np.poly1d(coef1)
fit2 = np.poly1d(coef2)

x1 = np.linspace(1,24,100)
x2 = np.linspace(12,62,100)

x_int = 17.8
y_int = 232141
# Out:
# fit linéaire : f(x) = 13040.472560975606 x + 29.03048780490971
# fit quadratique : g(x) = -66.2338643146685 x^2 + 12385.324945431847 x + 32687.848857410852

# %%
fig0, ax0 = plt.subplots()

ax0.plot(data_T5['exposure [s]'], data_T5['ADU'], color='k', marker='s', linestyle = 'none', label = 'Mesures')

ax0.plot(x1, fit1(x1), color='b', linestyle = '--', label=('Fit linéaire: $13040.47 x + 29.03$'))
ax0.plot(x2, fit2(x2), color='r', linestyle = '--', label=('Fit quadratique: $-66.23 x^2 + 12385.32 x + 32687.85$'))


ax0.plot(x_int, y_int, color='g', marker='s')

ax0.annotate('Intersection à (17.8 , 232141)', xy = (18.5, 225000), xycoords='data',
                xytext = (80,-70 ), textcoords = 'offset points',
                arrowprops = {'color': 'black', 'width': 1.5,
                              'headwidth': 8, 'alpha': 0.7},
                bbox=dict(boxstyle="round",pad=0.4, fc="none", ec="black"),
                fontsize=14)

ax0.set_title('Intensité lumineuse reçue pour HD5505 - T5', pad=20)
ax0.set_ylabel('Intensitée reçue [ADU]')
ax0.set_xlabel("Temps d'exposition [s]")
ax0.legend(loc='best', frameon=True)

plt.savefig('graphes/HD5505_T5.pdf', bbox_inches='tight')
plt.show()

# %%
coefn = 34936, 0
fitn = np.poly1d(coefn)
xn = np.linspace(0,9,100)

fign, axn = plt.subplots()

axn.plot(xn, fitn(xn), color='k', linestyle = '--')
axn.hlines(230000,0,7,colors='r', linestyles='dotted')
axn.vlines(6.58346691092283,0,255000,colors='r', linestyles='dotted')

axn.annotate('Intersection à (6.6 , 230000)', xy = (6.5, 235000), xycoords='data',
                xytext = (-270,50 ), textcoords = 'offset points',
                arrowprops = {'color': 'black', 'width': 1.5,
                              'headwidth': 8, 'alpha': 0.7},
                bbox=dict(boxstyle="round",pad=0.4, fc="none", ec="black"),
                fontsize=14)



axn.set_title('Intensité lumineuse théoriquement reçue pour AX Vel - T5', pad=20)
axn.set_ylabel('Intensitée reçue [ADU]')
axn.set_xlabel("Temps d'exposition [s]")
#axn.legend(loc='best', frameon=True)

plt.savefig('graphes/AXVEL_T5.pdf', bbox_inches='tight')
plt.show()
